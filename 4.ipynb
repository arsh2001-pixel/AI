# %%
#Q1
import copy
visited_states = []
# heuristic fn - number of misplaced blocks as compared to goal state 
def heuristic(curr_state,goal_state):
    goal_=goal_state[3]
    val=0
    for i in range(len(curr_state)):
        check_val=curr_state[i]
        if len(check_val)>0:
            for j in range(len(check_val)):
                for k in range(len(goal_)):
                  if check_val[j]==goal_[k]:
                    if j==0 and k==0:
                      val+=1
                      break
                    elif j==0 and k!=0:
                      val-=1
                      break
                    elif j!=0 and k==0:
                      val-=1
                      break    
                    elif check_val[j-1]==goal_[k-1]:
                      val+=1
                      break
                    else:
                      val-=1
                      break
    return val
            
# generate next possible solution for the current state
def generate_next(curr_state,prev_heu,goal_state):
    global visited_states
    state = copy.deepcopy(curr_state)
    for i in range(len(state)):
        temp = copy.deepcopy(state)
        if len(temp[i]) > 0:
            elem = temp[i].pop()
            for j in range(len(temp)):
                temp1 = copy.deepcopy(temp)
                if j != i:
                    temp1[j] = temp1[j] + [elem]
                    if (temp1 not in visited_states):
                        curr_heu=heuristic(temp1,goal_state)
                        # if a better state than previous state of found
                        if curr_heu>prev_heu:
                            print("Current Heuristic is ",end="")
                            print(curr_heu)
                            print("Previous heuristic is ",end=" ")
                            print(prev_heu)
                            child = copy.deepcopy(temp1)
                            return child
    
    # no better soln than current state is possible
    return 0

def solution_(init_state,goal_state):
    global visited_states

    # checking if initial state is already the final state
    if (init_state == goal_state):
        print (goal_state)
        print("solution found!")
        return
    
    current_state = copy.deepcopy(init_state)
    
    # loop while goal is found or no better optimal solution is possible
    while(True):

        # add current state to visited to avoid repetition
        visited_states.append(copy.deepcopy(current_state))

        print(current_state)
        prev_heu=heuristic(current_state,goal_state)

        # generate possible better child from current state
        child = generate_next(current_state,prev_heu,goal_state)
        
        # No more better states are possible
        if child==0:
            print("Final state - ",current_state)
            return      
        # change current state to child
        current_state = copy.deepcopy(child)  
def solver():
    # maintaining a global visited to save all visited and avoid repetition & infinite loop condition
    global visited_states
    # inputs
    init_state = [[],[],[],['B','C','D','A']]
    goal_state = [[],[],[],['A','B','C','D']]
    # goal_state = [[],[],[],['A','D','C','B']]
    solution_(init_state,goal_state)
solver()
# Out:
# [[], [], [], ['B', 'C', 'D', 'A']]
# Current Heuristic is 2
# Previous heuristic is  0
# [['A'], [], [], ['B', 'C', 'D']]
# Final state -  [['A'], [], [], ['B', 'C', 'D']]

# %%
#Q2
import copy
visited_states = []
# heuristic fn - number of misplaced blocks as compared to goal state 
def heuristic(curr_state,goal_state):
    goal_=goal_state[3]
    val=0
    for i in range(len(curr_state)):
        check_val=curr_state[i]
        if len(check_val)>0:
            for j in range(len(check_val)):
              k=j
              f=0
              while(k>=0):
                if check_val[k]==goal_[k]:
                    f=1
                else:
                    f=0
                    break
                k-=1    
              if f==1:
                val+=j
              else:
                val-=j  
    return val
            
# generate next possible solution for the current state
def generate_next(curr_state,prev_heu,goal_state):
    global visited_states
    state = copy.deepcopy(curr_state)
    for i in range(len(state)):
        temp = copy.deepcopy(state)
        if len(temp[i]) > 0:
            elem = temp[i].pop()
            for j in range(len(temp)):
                temp1 = copy.deepcopy(temp)
                if j != i:
                    temp1[j] = temp1[j] + [elem]
                    if (temp1 not in visited_states):
                        curr_heu=heuristic(temp1,goal_state)
                        # if a better state than previous state of found
                        if curr_heu>prev_heu:
                            print("Current Heuristic is ",end="")
                            print(curr_heu)
                            print("Previous heuristic is ",end=" ")
                            print(prev_heu)
                            child = copy.deepcopy(temp1)
                            return child
    
    # no better soln than current state is possible
    return 0

def solution_(init_state,goal_state):
    global visited_states

    # checking if initial state is already the final state
    if (init_state == goal_state):
        print (goal_state)
        print("solution found!")
        return
    
    current_state = copy.deepcopy(init_state)
    
    # loop while goal is found or no better optimal solution is possible
    while(True):

        # add current state to visited to avoid repetition
        visited_states.append(copy.deepcopy(current_state))

        print(current_state)
        prev_heu=heuristic(current_state,goal_state)

        # generate possible better child from current state
        child = generate_next(current_state,prev_heu,goal_state)
        
        # No more better states are possible
        if child==0:
            print("Final state - ",current_state)
            return      
        # change current state to child
        current_state = copy.deepcopy(child)  
def solver():
    # maintaining a global visited to save all visited and avoid repetition & infinite loop condition
    global visited_states
    # inputs
    init_state = [[],[],[],['B','C','D','A']]
    goal_state = [[],[],[],['A','B','C','D']]
    # goal_state = [[],[],[],['A','D','C','B']]
    solution_(init_state,goal_state)
solver()
# Out:
# [[], [], [], ['B', 'C', 'D', 'A']]
# Current Heuristic is -3
# Previous heuristic is  -6
# [['A'], [], [], ['B', 'C', 'D']]
# Current Heuristic is -2
# Previous heuristic is  -3
# [['A', 'D'], [], [], ['B', 'C']]
# Current Heuristic is -1
# Previous heuristic is  -2
# [['A'], ['D'], [], ['B', 'C']]
# Current Heuristic is 0
# Previous heuristic is  -1
# [['A'], ['D'], ['C'], ['B']]
# Current Heuristic is 1
# Previous heuristic is  0
# [['A', 'B'], ['D'], ['C'], []]
# Current Heuristic is 3
# Previous heuristic is  1
# [['A', 'B', 'C'], ['D'], [], []]
# Current Heuristic is 6
# Previous heuristic is  3
# [['A', 'B', 'C', 'D'], [], [], []]
# Final state -  [['A', 'B', 'C', 'D'], [], [], []]

# %%
#Q3
import copy
visited_states = []
# heuristic fn - number of misplaced blocks as compared to goal state
def heuristic(curr_state,goal_state):
    goal_=goal_state[2]
    val=0
    for i in range(len(curr_state)):
        check_val=curr_state[i]
        if len(check_val)>0:
            for j in range(len(check_val)):
              k=j
              f=0
              while(k>=0):
                if check_val[k]==goal_[k]:
                    f=1
                else:
                    f=0
                    break
                k-=1    
              if f==1:
                val+=j
              else:
                val-=j  
    return val
            
# generate next possible solution for the current state
open=[]
closed=[]
def generate_next(curr_state,prev_heu,goal_state):
    global visited_states
    state = copy.deepcopy(curr_state)
    for i in range(len(state)):
        temp = copy.deepcopy(state)
        if len(temp[i]) > 0:
            elem = temp[i].pop()
            for j in range(len(temp)):
                temp1 = copy.deepcopy(temp)
                if j != i:
                    temp1[j] = temp1[j] + [elem]
                    if (temp1 not in visited_states):
                        curr_heu=heuristic(temp1,goal_state)
                        # print(open)
                        #if a better state than previous state of found
                        if curr_heu>prev_heu:
                            open.append((curr_heu,temp1))
                open.sort()
                if(len(open)>0):
                  child1=open.pop()
                  child=child1[1]
                  print("Current Heuristic is ",end="")
                  print(child1[0])
                  print("Previous heuristic is ",end=" ")
                  print(prev_heu)
                  #child = copy.deepcopy(temp1)
                  open.clear()
                  return child                    
    # no better soln than current state is possible
    return 0

def solution_(init_state,goal_state):
    global visited_states

    # checking if initial state is already the final state
    if (init_state == goal_state):
        print (goal_state)
        print("solution found!")
        return
    
    current_state = copy.deepcopy(init_state)
    
    # loop while goal is found or no better optimal solution is possible
    while(True):

        # add current state to visited to avoid repetition
        visited_states.append(copy.deepcopy(current_state))

        print(current_state)
        prev_heu=heuristic(current_state,goal_state)

        # generate possible better child from current state
        child = generate_next(current_state,prev_heu,goal_state)
        
        # No more better states are possible
        if child==0:
            print("Final state - ",current_state)
            return      
        # change current state to child
        current_state = copy.deepcopy(child)  
def solver():
    # maintaining a global visited to save all visited and avoid repetition & infinite loop condition
    global visited_states
    # inputs
    init_state = [[],['B'],['C','A']]
    goal_state = [[],[],['A','B','C']]
    solution_(init_state,goal_state)
solver()
# Out:
# [[], ['B'], ['C', 'A']]
# Current Heuristic is 0
# Previous heuristic is  -1
# [['A'], ['B'], ['C']]
# Current Heuristic is 1
# Previous heuristic is  0
# [['A', 'B'], [], ['C']]
# Current Heuristic is 3
# Previous heuristic is  1
# [['A', 'B', 'C'], [], []]
# Final state -  [['A', 'B', 'C'], [], []]

# %%
from collections import defaultdict
 
# function to add an edge to graph
beamWidth=2
h=[]
open=[]
closed=[]
fli=[]
def addEdge(u,v):
    graph[u].append(v)
 
# Function to print a BFS of graph
def Beam(s):
    # Mark all the vertices as not visited
    visited = [False] * (7)
 
    # Mark the source node as
    # visited and enqueue it
    open.append(s)
    while open:
        # Dequeue a vertex from
        # queue and print it
        s =open.pop(0)
        print (s, end = " ")
        closed.append(s)
        # Get all adjacent vertices of the
        # dequeued vertex s. If a adjacent
        # has not been visited, then mark it
        # visited and enqueue it
        for i in graph[s]:
            if visited[i] == False:
                open.append(i)
                visited[i]=True
        for i in range(len(open)):
          h.append(hv[open[i]])
          a=h.index(min(h))
          h.pop(a)
          fli.append(open[a])
          if(len(fli)==beamWidth):
            break        
#graph
graph =defaultdict(list)
addEdge(0, 1)
addEdge(0, 2)
addEdge(1, 3)
addEdge(1, 4)
addEdge(3, 5)
addEdge(3, 6)
# addedge('A','B')
# addedge('A','C')
# addedge('B', 'D')
# addedge('B', 'E')
# addedge('C', 'F')
# addedge('C', 'G')
hv= {0: -1, 1: 1, 2:3 ,3:2,4:2,5:3,6:0}
Beam(0)

#######################3Unsucessful
# Out:
# 0 1 2 3 4 5 6

# %%
beamwidth=int(input("Enter the beam width"))
from collections import defaultdict
from queue import PriorityQueue
def add_edge( u, v, weight):
    #Add Edges between two nodes along with weight
    #as Algorithm is of Uniform Cost Search""
    if directed:
        value=(weight, v)
        graph[u].append (value)
    else:
        value = ( weight,v)
        graph[u].append (value)
        value = (weight,u)
        graph[v].append (value)
def beam( current_node, goal_node):
    #"*"It takes starting node and goal node as parameters then
    # it returns a path using Uniform Cost Search Algorithm""
    visited =[]
    queue=PriorityQueue()
    queue1=PriorityQueue()
    queue.put ( (0, current_node))
    while not queue.empty():

        item= queue.get()
        current_node = item[1]
        if current_node==goal_node:
          print(current_node, end = " ")
          visited.append(item[1])
          queue.queue.clear()
        else:
            if current_node in visited:
                continue
            print(current_node, end = " ")
            visited.append(current_node)
            for neighbour in graph[current_node]:
                    queue.put((neighbour[0], neighbour[1]))
            for i in range(queue.qsize()):
              it=queue.get()
              # print(it)
              if queue1.qsize()==beamwidth:
                break
              else:  
                queue1.put(it)     
            queue.queue.clear()
            for i in range(queue1.qsize()):
              it=queue1.get()
              queue.put(it)



                    
directed=True
graph =defaultdict(list)
add_edge('A','B',1)
add_edge('A','C',3)
add_edge('B', 'D', 2)
add_edge('B', 'E', 2)
add_edge('C', 'F', 3)
add_edge('C', 'G', 0)
print(graph)
beam('A','G')
# Out:
# Enter the beam width3
# defaultdict(<class 'list'>, {'A': [(1, 'B'), (3, 'C')], 'B': [(2, 'D'), (2, 'E')], 'C': [(3, 'F'), (0, 'G')]})
# A B D E C G
